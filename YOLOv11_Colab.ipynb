# %% [markdown]
# <a href="https://colab.research.google.com/github/melissa19120519639/YOLOv11-for-deploying/blob/main/YOLOv11_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
# !unzip /content/robotflow/datasets.zip -d /content/
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-212_jpg.rf.1e8561703c71365c0fed5b3bf9ae055c.txt
#   inflating: /content/train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-212_jpg.rf.6d343393e00bb5cdd53ba41620c2805d.txt
#   inflating: /content/train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-212_jpg.rf.7653f90d0a71d91fb45908be2cfb2ef9.txt
#   inflating: /content/train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-214_jpg.rf.14f2adf12c2c9bc458d9495b8ec61076.txt
#   inflating: /content/train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-214_jpg.rf.6d5bc1bd3db6b53f0951763b33f8fe3c.txt
#   inflating: /content/train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-214_jpg.rf.9fe36597c1505ea00935f4d1e1285ded.txt
#   inflating: /content/train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-215_jpg.rf.323f75af9cc2a439a8ed0b738864b30c.txt
# ...

# %%
# 递归创建目标目录（即使 datasets 不存在也会自动创建）
# !mkdir -p /content/datasets

# %%
# 使用 mv 命令移动文件夹（保留文件夹结构）
# !mv /content/test/ /content/datasets/

# %%
# !mv /content/train/ /content/datasets/

# %%
# !mv /content/valid/ /content/datasets/

# %%
! pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
###训练模型
from ultralytics import YOLO


def train_model():

    model = YOLO("/content/yolo11n.pt")
    model.train(
        data="/content/datasets/data.yaml",  # path to dataset YAML
        epochs=30,  # number of training epochs
        imgsz=640,  # training image size
        #workers = 4,
        batch = 4
        # device="cpu",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
    )


if __name__ == '__main__':
    train_model()
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
2+2
# Out:
# 4
